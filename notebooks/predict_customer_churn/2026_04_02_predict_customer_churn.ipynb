# %%
# %load_ext autoreload
# %autoreload 2

# %reload_ext autoreload

import ds_tutor
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ds_tutor import Project, kaggle_dataset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from ds_tutor import Project, kaggle_dataset
#
# ImportError: cannot import name 'kaggle_dataset' from 'ds_tutor' (C:\Users\zak\Projects\PyCharmProjects\ds-tutor\src\ds_tutor\__init__.py)

# %%
customer_churn = Project('customer_churn', )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 customer_churn = Project('customer_churn', )
#
# TypeError: Project.__init__() missing 2 required positional arguments: 'df' and 'target_col'
